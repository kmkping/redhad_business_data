# %%
import numpy as np
import pandas as pd
import xgboost as xgb

from xgboost.sklearn import XGBClassifier

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.datasets import make_classification
from sklearn.model_selection  import StratifiedKFold, KFold, train_test_split
from scipy.stats import randint, uniform
from sklearn.metrics import roc_auc_score

import datetime
import random
from operator import itemgetter
import time
import copy

# %%
act_train_data = pd.read_csv("datasets/act_train.csv", dtype={'people_id':np.str, 'activity_id': np.str, 'outcome': np.int8}, parse_dates=['date'])
act_test_data  = pd.read_csv("datasets/act_test.csv", dtype={'people_id': np.str, 'activity_id': np.str}, parse_dates=['date'])
people_data = pd.read_csv("datasets/people.csv", dtype={'people_id': np.str,'activity_id': np.str, 'char_38':np.int32}, parse_dates=['date'])

# %%
act_train_data.drop('char_10', axis=1)
act_test_data.drop('char_10', axis=1)
# Out:
#          people_id   activity_id       date activity_category   char_1  \
# 0       ppl_100004   act1_249281 2022-07-20            type 1   type 5
# 1       ppl_100004   act2_230855 2022-07-20            type 5      NaN
# 2        ppl_10001   act1_240724 2022-10-14            type 1  type 12
# 3        ppl_10001    act1_83552 2022-11-27            type 1  type 20
# 4        ppl_10001  act2_1043301 2022-10-15            type 5      NaN
# 5        ppl_10001   act2_112890 2022-11-27            type 5      NaN
# 6        ppl_10001  act2_1169930 2022-10-15            type 5      NaN
# 7        ppl_10001  act2_1924448 2022-10-15            type 5      NaN
# 8        ppl_10001  act2_1953554 2022-10-15            type 5      NaN
# 9        ppl_10001  act2_1971739 2022-11-28            type 5      NaN
# 10       ppl_10001  act2_2839282 2022-10-16            type 5      NaN
# 11       ppl_10001  act2_2889351 2022-11-27            type 5      NaN
# 12       ppl_10001  act2_3238933 2022-10-15            type 5      NaN
# 13       ppl_10001  act2_3384798 2022-10-15            type 5      NaN
# 14       ppl_10001  act2_3701358 2022-11-27            type 5      NaN
# 15       ppl_10001  act2_3715695 2022-10-15            type 5      NaN
# 16       ppl_10001  act2_3734085 2022-11-27            type 5      NaN
# 17       ppl_10001  act2_3961391 2022-10-16            type 5      NaN
# 18       ppl_10001  act2_4167474 2022-10-15            type 5      NaN
# 19       ppl_10001  act2_4397847 2022-10-15            type 5      NaN
# 20       ppl_10001  act2_4649285 2022-10-15            type 5      NaN
# 21       ppl_10001   act2_538607 2022-10-15            type 5      NaN
# 22       ppl_10001   act2_584216 2022-11-27            type 5      NaN
# 23       ppl_10001   act2_596561 2022-10-15            type 5      NaN
# 24       ppl_10001   act2_649143 2022-11-27            type 5      NaN
# 25       ppl_10001   act2_659237 2022-10-16            type 5      NaN
# 26       ppl_10001   act2_688604 2022-11-28            type 5      NaN
# 27      ppl_100010   act1_218751 2022-09-01            type 1   type 2
# 28      ppl_100010   act1_383524 2022-09-01            type 1   type 2
# 29      ppl_100010  act2_3973689 2022-09-01            type 3      NaN
# ...            ...           ...        ...               ...      ...
# 498657   ppl_99963  act2_3146168 2023-07-20            type 5      NaN
# 498658   ppl_99963  act2_3435600 2023-07-01            type 5      NaN
# 498659   ppl_99963  act2_3648161 2023-07-20            type 5      NaN
# 498660   ppl_99963  act2_4609368 2023-06-30            type 5      NaN
# 498661   ppl_99963   act2_488594 2023-07-20            type 5      NaN
# 498662   ppl_99963   act2_568974 2023-06-25            type 3      NaN
# 498663   ppl_99975   act1_187412 2023-06-28            type 1   type 1
# 498664   ppl_99975  act2_1907199 2023-06-29            type 3      NaN
# 498665   ppl_99975  act2_3825329 2023-06-29            type 7      NaN
# 498666   ppl_99975  act2_4540493 2023-06-29            type 2      NaN
# 498667   ppl_99975  act2_4716058 2023-06-29            type 4      NaN
# 498668   ppl_99986  act2_1374659 2022-09-15            type 2      NaN
# 498669   ppl_99986  act2_4191036 2022-09-15            type 4      NaN
# 498670   ppl_99997  act2_1893941 2022-10-18            type 2      NaN
# 498671   ppl_99997  act2_2245699 2023-08-15            type 2      NaN
# 498672   ppl_99997  act2_2316472 2023-06-08            type 2      NaN
# 498673   ppl_99997  act2_2372813 2023-04-22            type 2      NaN
# 498674   ppl_99997  act2_2433185 2022-09-24            type 2      NaN
# 498675   ppl_99997  act2_2576346 2022-11-29            type 2      NaN
# 498676   ppl_99997  act2_2718841 2022-11-25            type 2      NaN
# 498677   ppl_99997  act2_2902742 2022-09-13            type 2      NaN
# 498678   ppl_99997  act2_3448131 2023-06-08            type 2      NaN
# 498679   ppl_99997  act2_3757705 2022-08-09            type 2      NaN
# 498680   ppl_99997  act2_4149173 2022-11-05            type 2      NaN
# 498681   ppl_99997  act2_4355610 2023-06-10            type 2      NaN
# 498682   ppl_99997  act2_4367092 2023-04-22            type 2      NaN
# 498683   ppl_99997  act2_4404220 2022-11-12            type 2      NaN
# 498684   ppl_99997   act2_448830 2022-08-02            type 2      NaN
# 498685   ppl_99997   act2_450133 2022-08-02            type 2      NaN
# 498686   ppl_99997   act2_847967 2022-10-15            type 2      NaN
#
#          char_2  char_3  char_4  char_5  char_6  char_7   char_8   char_9
# 0       type 10  type 5  type 1  type 6  type 1  type 1   type 7   type 4
# 1           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 2        type 1  type 5  type 4  type 6  type 1  type 1  type 13  type 10
# 3       type 10  type 5  type 4  type 6  type 1  type 1   type 5   type 5
# 4           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 5           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 6           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 7           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 8           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 9           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 10          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 11          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 12          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 13          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 14          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 15          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 16          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 17          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 18          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 19          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 20          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 21          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 22          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 23          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 24          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 25          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 26          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 27       type 1  type 9  type 3  type 1  type 3  type 2   type 2   type 1
# 28       type 1  type 5  type 3  type 1  type 3  type 1   type 2   type 1
# 29          NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# ...         ...     ...     ...     ...     ...     ...      ...      ...
# 498657      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498658      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498659      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498660      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498661      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498662      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498663   type 6  type 2  type 2  type 1  type 1  type 1   type 2   type 1
# 498664      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498665      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498666      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498667      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498668      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498669      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498670      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498671      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498672      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498673      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498674      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498675      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498676      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498677      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498678      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498679      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498680      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498681      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498682      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498683      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498684      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498685      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 498686      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
#
# [498687 rows x 13 columns]

# %%
print("Train data shape: " + format(act_train_data.shape))
print("Test data shape: " + format(act_test_data.shape))
print("People data shape: " + format(people_data.shape))
# Out:
# Train data shape: (2197291, 15)
# Test data shape: (498687, 14)
# People data shape: (189118, 41)

# %%
def act_data_treatment(dsname):
    dataset = dsname
    
    for col in list(dataset.columns):
        if col not in ['people_id', 'activity_id', 'date', 'char_38', 'outcome']:
            if dataset[col].dtype == 'object':
                dataset[col].fillna('type 0', inplace=True)
                dataset[col] = dataset[col].apply(lambda x: x.split(' ')[1]).astype(np.int32)
            elif dataset[col].dtype == 'bool':
                dataset[col] = dataset[col].astype(np.int8)
    
    dataset = dataset.drop('date', axis =1)
    return dataset

# %%
act_train_data  = act_data_treatment(act_train_data)
act_test_data = act_data_treatment(act_test_data)
people_data = act_data_treatment(people_data)

# %%
#merge people and train dataset
train = act_train_data.merge(people_data, on='people_id', how='left', left_index=True)
test  = act_test_data.merge(people_data, on='people_id', how='left', left_index=True)

# %%
train.columns
# Out:
# Index(['people_id', 'activity_id', 'activity_category', 'char_1_x', 'char_2_x',
#        'char_3_x', 'char_4_x', 'char_5_x', 'char_6_x', 'char_7_x', 'char_8_x',
#        'char_9_x', 'char_10_x', 'outcome', 'char_1_y', 'group_1', 'char_2_y',
#        'char_3_y', 'char_4_y', 'char_5_y', 'char_6_y', 'char_7_y', 'char_8_y',
#        'char_9_y', 'char_10_y', 'char_11', 'char_12', 'char_13', 'char_14',
#        'char_15', 'char_16', 'char_17', 'char_18', 'char_19', 'char_20',
#        'char_21', 'char_22', 'char_23', 'char_24', 'char_25', 'char_26',
#        'char_27', 'char_28', 'char_29', 'char_30', 'char_31', 'char_32',
#        'char_33', 'char_34', 'char_35', 'char_36', 'char_37', 'char_38'],
#       dtype='object')

# %%
del act_train_data
del act_test_data
del people_data

# %%
train = train.sort_values(['people_id'], ascending=[1])
test = test.sort_values(['people_id'], ascending=[1])#test=test.sort_values(['people_id'], ascending=[1])

# %%
train_columns = train.columns.values
test_columns = test.columns.values
features = list(set(train_columns) & set(test_columns))

# %%
len(feature)
# Out:
# 52

# %%
train.shape
# Out:
# (2197291, 53)

# %%
test.shape
# Out:
# (498687, 52)

# %%
train.fillna('NA', inplace=True)
test.fillna('NA', inplace=True)
y= train.outcome
train=train.drop('outcome', axis=1)

# %%
whole = pd.concat([train,test], ignore_index=True)

# %%
def reduce_dimen(dataset,column,toreplace):
    for index,i in dataset[column].duplicated(keep=False).iteritems():
        if i==False:
            dataset.set_value(index,column,toreplace)
    return dataset

# %%
categorical=['group_1','activity_category','char_1_x','char_2_x','char_3_x','char_4_x','char_5_x','char_6_x','char_7_x','char_8_x','char_9_x','char_2_y','char_3_y','char_4_y','char_5_y','char_6_y','char_7_y','char_8_y','char_9_y']
for category in categorical:
    whole=reduce_dimen(whole,category,9999999)
# Out:
# /Users/kyu.kim@ibm.com/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
X = whole[:len(train)]
X_test = whole[len(train):]

# %%
del train
del whole

# %%
X.shape
# Out:
# (2197291, 52)

# %%
X_test.shape
# Out:
# (498687, 52)

# %%
X=X.sort_values(['people_id'],ascending=[1])
X = X[features].drop(['people_id', 'activity_id', 'char_1_y'], axis=1)

# %%
#list categorical features and label them
from sklearn.preprocessing import LabelEncoder

# %%
categorical=['group_1','activity_category','char_1_x','char_2_x','char_3_x','char_4_x','char_5_x','char_6_x','char_7_x','char_8_x','char_9_x','char_2_y','char_3_y','char_4_y','char_5_y','char_6_y','char_7_y','char_8_y','char_9_y']
not_categorical=[]
for category in X.columns:
    if category not in categorical:
        not_categorical.append(category)
    else:
        temp = pd.concat([X[category], X_test[category]])
        le=LabelEncoder()
        le.fit(temp.values)
        X[category] = le.transform(X[category].values)
        X_test[category] = le.transform(X_test[category].values) 
        
enc = OneHotEncoder(handle_unknown='ignore')
enc=enc.fit(pd.concat([X[categorical],X_test[categorical]]))
X_cat_sparse=enc.transform(X[categorical])
X_test_cat_sparse=enc.transform(X_test[categorical])

# %%
X[not_categorical].shape, X[categorical].shape, X_test[not_categorical].shape, X_test[categorical].shape
# Out:
# ((2197291, 30), (2197291, 19), (498687, 30), (498687, 19))

# %%
from scipy.sparse import hstack
X_sparse=hstack((X[not_categorical], X_cat_sparse))
X_test_sparse=hstack((X_test[not_categorical], X_test_cat_sparse))

print("Training data: " + format(X_sparse.shape))
print("Test data: " + format(X_test_sparse.shape))
print("###########")
print("One Hot enconded Test Dataset Script")
# Out:
# Training data: (2197291, 31263)
# Test data: (498687, 31263)
# ###########
# One Hot enconded Test Dataset Script

# %%
dtrain = xgb.DMatrix(X_sparse,label=y)
dtest = xgb.DMatrix(X_test_sparse)

param = {'max_depth':10, 'eta':0.02, 'silent':0, 'objective':'binary:logistic' }
#param['nthread'] = 2
param['eval_metric'] = 'auc'
param['subsample'] = 0.7
param['colsample_bytree']= 0.7
param['min_child_weight'] = 0
param['booster'] = "gblinear"
# Out:
# /Users/kyu.kim@ibm.com/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/kyu.kim@ibm.com/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
np.random.seed(120)
evals  = [(dtrain,'train')]
num_round = 305
bst = xgb.train(param, dtrain, num_round, evals, early_stopping_rounds=10, verbose_eval=10)

# %%
ypred=bst.predict(dtest)
output=pd.DataFrame({'activity_id': test['activity_id'],'outcome':ypred})
output.head()
output.to_csv('without_leak.csv', index = False)
# !zip subb.zip without_leak.csv
